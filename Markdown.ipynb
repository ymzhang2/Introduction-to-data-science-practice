# %% [markdown]
# # This is an tag
# ### This is an tag
# ######## This is an tag

# %% [markdown]
# *This text will be italic*
# **This text will be bold**
# __This text will also be bold__
# _This will also be italic_
# *You **can** combine them*

# %% [markdown]
# * Item 1
# * Item 2
#   * Item 1a
#   * Item 2a

# %% [markdown]
# 1. Item 1
# 2. Item 2
# 3. Item 3
#    * Item 3a
#    * Item 3b

# %% [markdown]
# ![GitHub Logo] (/image/logo.png)
# Format: ![Alt Text](url)

# %% [markdown]
# http://github.com - automatic
# [GitHub](http://github.com)

# %% [markdown]
# ![my picture] (/Users/yimanzhang/Desktop/peafowl.png)

# %% [markdown]
# [mygithub](https://github.com/ymzhang2)

# %% [markdown]
# [Makrdown_Tutorial](https://guides.github.com/features/mastering-markdown)

# %% [markdown]
# I think you should use an `http://yimanzhang` element here instead

# %% [markdown]
# as kanye west said:
# > we're living the future so
# > the present is our past

# %% [markdown]
# - [x] @mentions, #refs, [links](url), **formatting**, and **<del>tags</del>** supported
# - [x] list syntax requred(any unorder or orered list supported)
# - [x] this is a complete item
# - [ ] this is an incomplete item

# %% [markdown]
# First Header | Second Header| third Headersssss
# ------------ | -------------|------------------
# content from cell 1 | ** content from cell 2** | _content from cell 3_
# # content in the first column | ## content in the second column | ### content in the third column

# %% [markdown]
# :sunny:

# %%
from IPython.display import Image
Image(filename=("/Users/yimanzhang/Desktop/peafowl.png"))
